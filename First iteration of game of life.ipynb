# %%
import turtle
import random
import math

# Define constants
WIDTH = 600
HEIGHT = 600
DOT_SIZE_RANGE = (1, 10)
DOT_SPEED_RANGE = (1, 10)
BG_COLOR = "white"
DOT_COLORS = ["red", "green", "blue", "yellow", "cyan", "magenta", "orange", "pink", "brown", "gray"]

# Define Dot class
class Dot:
    def __init__(self, pos):
        self.size = random.randint(*DOT_SIZE_RANGE)
        self.color = random.choice(DOT_COLORS)
        self.speed = random.randint(*DOT_SPEED_RANGE)
        self.direction = random.uniform(0, 2 * math.pi)
        self.pos = pos
    
    def update(self):
        # Move dot based on speed and direction
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.pos = (self.pos[0] + dx, self.pos[1] + dy)
        
        # Change direction at random intervals
        if random.random() < 0.1:
            self.direction = random.uniform(0, 2 * math.pi)
    
    def draw(self, t):
        # Draw dot on turtle
        t.penup()
        t.goto(*self.pos)
        t.pendown()
        t.dot(self.size, self.color)

# Define main function
def main():
    # Initialize turtle
    screen = turtle.Screen()
    screen.setup(WIDTH, HEIGHT)
    screen.bgcolor(BG_COLOR)
    screen.title("Game of Life Simulation")
    
    # Create turtle
    t = turtle.Turtle()
    t.hideturtle()
    t.speed(0)
    
    # Create list of dots
    dots = [Dot((random.randint(-WIDTH//2, WIDTH//2), random.randint(-HEIGHT//2, HEIGHT//2))) for i in range(50)]
    
    # Run simulation loop
    running = True
    while running:
        # Update dots
        for dot in dots:
            dot.update()
        
        # Check for collisions
        i = 0
        while i < len(dots):
            j = i + 1
            while j < len(dots):
                if math.dist(dots[i].pos, dots[j].pos) <= dots[i].size + dots[j].size:
                    if dots[i].size > dots[j].size:
                        dots[i].size += 1
                        dots.pop(j)
                        j -= 1
                    else:
                        dots[j].size += 1
                        dots.pop(i)
                        i -= 1
                        break
                j += 1
            i += 1
        
        # Clear turtle
        t.clear()
        
        # Draw dots
        for dot in dots:
            dot.draw(t)
        
        # Update screen
        screen.update()
    
    # Quit turtle
    screen.bye()

# Run main function
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-f0d72e40028f> in <module>
#      93 # Run main function
#      94 if __name__ == "__main__":
# ---> 95     main()
#
# <ipython-input-1-f0d72e40028f> in main()
#      83         # Draw dots
#      84         for dot in dots:
# ---> 85             dot.draw(t)
#      86
#      87         # Update screen
#
# <ipython-input-1-f0d72e40028f> in draw(self, t)
#      33         # Draw dot on turtle
#      34         t.penup()
# ---> 35         t.goto(*self.pos)
#      36         t.pendown()
#      37         t.dot(self.size, self.color)
#
# ~\anaconda3\lib\turtle.py in goto(self, x, y)
#    1774             self._goto(Vec2D(*x))
#    1775         else:
# -> 1776             self._goto(Vec2D(x, y))
#    1777
#    1778     def home(self):
#
# ~\anaconda3\lib\turtle.py in _goto(self, end)
#    3156                       (self.currentLineItem,
#    3157                       self.currentLine[:],
# -> 3158                       screen._pointlist(self.currentLineItem),
#    3159                       self.items[:])
#    3160                       )
#
# ~\anaconda3\lib\turtle.py in _pointlist(self, item)
#     753         (9.9999999999999982, 0.0)]
#     754         >>> """
# --> 755         cl = self.cv.coords(item)
#     756         pl = [(cl[i], -cl[i+1]) for i in range(0, len(cl), 2)]
#     757         return  pl
#
# <string> in coords(self, *args, **kw)
#
# ~\anaconda3\lib\tkinter\__init__.py in coords(self, *args)
#    2759         return [self.tk.getdouble(x) for x in
#    2760                            self.tk.splitlist(
# -> 2761                    self.tk.call((self._w, 'coords') + args))]
#    2762
#    2763     def _create(self, itemType, args, kw): # Args: (val, val, ..., cnf={})
#
# TclError: invalid command name ".!canvas"
